# %% [markdown]
# # WSA Pandas Demo Complete

# %% [markdown]
# ### Imports
# * The `pandas` library should already be installed as part of the Anaconda distribution
# * Typically abbreviated as `pd`

# %%
import pandas as pd

# %% [markdown]
# ### Reading in a DataFrame
# * We will start by creating a dataframe called `df` containing the Michigan Football GameLog data we have stored in our SQL database.
# * This data will be exported and read into Jupyter notebook as a `.csv` file.
# * Make sure your `.csv` file is stored in the same folder as this notebook.

# %%
# .read_csv()
# drop unneeded id column with .drop()
df = pd.read_csv('Michigan_GameLogs_F24.csv').drop(columns=['id'])
df
# Out:
#            date  year             opponent home_away result  points_scored  \
# 0    2011-09-03  2011     Western Michigan      Home      W             34
# 1    2011-09-10  2011           Notre Dame      Home      W             35
# 2    2011-09-17  2011     Eastern Michigan      Home      W             31
# 3    2011-09-24  2011      San Diego State      Home      W             28
# 4    2011-10-01  2011            Minnesota      Home      W             58
# ..          ...   ...                  ...       ...    ...            ...
# 167  2024-09-14  2024       Arkansas State      Home      W             28
# 168  2024-09-21  2024  Southern California      Home      W             27
# 169  2024-09-28  2024            Minnesota      Home      W             27
# 170  2024-10-05  2024           Washington      Away      L             17
# 171  2024-10-19  2024             Illinois      Away      L              7
#
#      points_against  pass_cmp  pass_att  pass_pct  pass_yrds  pass_td  \
# 0                10         9        13      69.2         98        0
# 1                31        11        24      45.8        338        4
# 2                 3         7        18      38.9         95        2
# 3                 7         8        17      47.1         93        0
# 4                 0        18        25      72.0        217        3
# ..              ...       ...       ...       ...        ...      ...
# 167              18        13        18      72.2        134        1
# 168              24         7        12      58.3         32        0
# 169              24        10        18      55.6         86        1
# 170              27        13        25      52.0        113        1
# 171              21        20        32      62.5        208        0
#
#      pass_1st_down  rush_att  rush_yrds  rush_td  rush_1st_down  \
# 0                5        26        190        3              9
# 1               10        26        114        1              5
# 2                5        50        376        2             19
# 3                3        45        320        4             14
# 4               10        48        363        3             19
# ..             ...       ...        ...      ...            ...
# 167              6        44        301        3             14
# 168              0        46        290        3             12
# 169              5        43        155        2              9
# 170              7        37        174        1              9
# 171              8        38        114        1             10
#
#      total_offense  fumbles  ints
# 0              288        0     0
# 1              452        0     3
# 2              471        0     1
# 3              413        2     2
# 4              580        0     0
# ..             ...      ...   ...
# 167            435        0     3
# 168            322        2     0
# 169            241        0     1
# 170            287        1     1
# 171            322        2     1
#
# [172 rows x 20 columns]

# %%
# .head() shows first 5 rows
df.head()
# Out:
#          date  year          opponent home_away result  points_scored  \
# 0  2011-09-03  2011  Western Michigan      Home      W             34
# 1  2011-09-10  2011        Notre Dame      Home      W             35
# 2  2011-09-17  2011  Eastern Michigan      Home      W             31
# 3  2011-09-24  2011   San Diego State      Home      W             28
# 4  2011-10-01  2011         Minnesota      Home      W             58
#
#    points_against  pass_cmp  pass_att  pass_pct  pass_yrds  pass_td  \
# 0              10         9        13      69.2         98        0
# 1              31        11        24      45.8        338        4
# 2               3         7        18      38.9         95        2
# 3               7         8        17      47.1         93        0
# 4               0        18        25      72.0        217        3
#
#    pass_1st_down  rush_att  rush_yrds  rush_td  rush_1st_down  total_offense  \
# 0              5        26        190        3              9            288
# 1             10        26        114        1              5            452
# 2              5        50        376        2             19            471
# 3              3        45        320        4             14            413
# 4             10        48        363        3             19            580
#
#    fumbles  ints
# 0        0     0
# 1        0     3
# 2        0     1
# 3        2     2
# 4        0     0

# %%
# .tail() shows last 5 rows
df.tail()
# Out:
#            date  year             opponent home_away result  points_scored  \
# 167  2024-09-14  2024       Arkansas State      Home      W             28
# 168  2024-09-21  2024  Southern California      Home      W             27
# 169  2024-09-28  2024            Minnesota      Home      W             27
# 170  2024-10-05  2024           Washington      Away      L             17
# 171  2024-10-19  2024             Illinois      Away      L              7
#
#      points_against  pass_cmp  pass_att  pass_pct  pass_yrds  pass_td  \
# 167              18        13        18      72.2        134        1
# 168              24         7        12      58.3         32        0
# 169              24        10        18      55.6         86        1
# 170              27        13        25      52.0        113        1
# 171              21        20        32      62.5        208        0
#
#      pass_1st_down  rush_att  rush_yrds  rush_td  rush_1st_down  \
# 167              6        44        301        3             14
# 168              0        46        290        3             12
# 169              5        43        155        2              9
# 170              7        37        174        1              9
# 171              8        38        114        1             10
#
#      total_offense  fumbles  ints
# 167            435        0     3
# 168            322        2     0
# 169            241        0     1
# 170            287        1     1
# 171            322        2     1

# %%
# .head(n) shows first n rows
df.head(2)
# Out:
#          date  year          opponent home_away result  points_scored  \
# 0  2011-09-03  2011  Western Michigan      Home      W             34
# 1  2011-09-10  2011        Notre Dame      Home      W             35
#
#    points_against  pass_cmp  pass_att  pass_pct  pass_yrds  pass_td  \
# 0              10         9        13      69.2         98        0
# 1              31        11        24      45.8        338        4
#
#    pass_1st_down  rush_att  rush_yrds  rush_td  rush_1st_down  total_offense  \
# 0              5        26        190        3              9            288
# 1             10        26        114        1              5            452
#
#    fumbles  ints
# 0        0     0
# 1        0     3

# %% [markdown]
# ### Data Preprocessing

# %%
# .info() provides essential details for your dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            172 non-null    object
#  1   year            172 non-null    int64
#  2   opponent        172 non-null    object
#  3   home_away       172 non-null    object
#  4   result          172 non-null    object
#  5   points_scored   172 non-null    int64
#  6   points_against  172 non-null    int64
#  7   pass_cmp        172 non-null    int64
#  8   pass_att        172 non-null    int64
#  9   pass_pct        172 non-null    float64
#  10  pass_yrds       172 non-null    int64
#  11  pass_td         172 non-null    int64
#  12  pass_1st_down   172 non-null    int64
#  13  rush_att        172 non-null    int64
#  14  rush_yrds       172 non-null    int64
#  15  rush_td         172 non-null    int64
#  16  rush_1st_down   172 non-null    int64
#  17  total_offense   172 non-null    int64
#  18  fumbles         172 non-null    int64
#  19  ints            172 non-null    int64
# dtypes: float64(1), int64(15), object(4)
# memory usage: 27.0+ KB

# %%
# .shape shows dimensions of df (num_rows, num_cols)
df.shape
# Out:
# (172, 20)

# %% [markdown]
# #### Null and Duplicate Values

# %%
# We can append dataframes to each other using pd.concat()
# It is good practice to never change or update the original df directly
# Always create copies!

temp_df = pd.concat([df,df])
temp_df.shape
# Out:
# (344, 20)

# %%
# We can also remove duplicate values with .drop_duplicates()
temp_df.drop_duplicates().shape
# Out:
# (172, 20)

# %%
# .isnull() checks for NULL or empty datapoints 
# returns True for any values that are NULL
df.isnull()
# Out:
#       date   year  opponent  home_away  result  points_scored  points_against  \
# 0    False  False     False      False   False          False           False
# 1    False  False     False      False   False          False           False
# 2    False  False     False      False   False          False           False
# 3    False  False     False      False   False          False           False
# 4    False  False     False      False   False          False           False
# ..     ...    ...       ...        ...     ...            ...             ...
# 167  False  False     False      False   False          False           False
# 168  False  False     False      False   False          False           False
# 169  False  False     False      False   False          False           False
# 170  False  False     False      False   False          False           False
# 171  False  False     False      False   False          False           False
#
#      pass_cmp  pass_att  pass_pct  pass_yrds  pass_td  pass_1st_down  \
# 0       False     False     False      False    False          False
# 1       False     False     False      False    False          False
# 2       False     False     False      False    False          False
# 3       False     False     False      False    False          False
# 4       False     False     False      False    False          False
# ..        ...       ...       ...        ...      ...            ...
# 167     False     False     False      False    False          False
# 168     False     False     False      False    False          False
# 169     False     False     False      False    False          False
# 170     False     False     False      False    False          False
# 171     False     False     False      False    False          False
#
#      rush_att  rush_yrds  rush_td  rush_1st_down  total_offense  fumbles  \
# 0       False      False    False          False          False    False
# 1       False      False    False          False          False    False
# 2       False      False    False          False          False    False
# 3       False      False    False          False          False    False
# 4       False      False    False          False          False    False
# ..        ...        ...      ...            ...            ...      ...
# 167     False      False    False          False          False    False
# 168     False      False    False          False          False    False
# 169     False      False    False          False          False    False
# 170     False      False    False          False          False    False
# 171     False      False    False          False          False    False
#
#       ints
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 167  False
# 168  False
# 169  False
# 170  False
# 171  False
#
# [172 rows x 20 columns]

# %%
# .sum() gets a summary of the above df
df.isnull().sum()
# Out:
# date              0
# year              0
# opponent          0
# home_away         0
# result            0
# points_scored     0
# points_against    0
# pass_cmp          0
# pass_att          0
# pass_pct          0
# pass_yrds         0
# pass_td           0
# pass_1st_down     0
# rush_att          0
# rush_yrds         0
# rush_td           0
# rush_1st_down     0
# total_offense     0
# fumbles           0
# ints              0
# dtype: int64

# %%
# If we did have null values, we could use the .dropna() function to remove all rows with null values
df.dropna()
# Out:
#            date  year             opponent home_away result  points_scored  \
# 0    2011-09-03  2011     Western Michigan      Home      W             34
# 1    2011-09-10  2011           Notre Dame      Home      W             35
# 2    2011-09-17  2011     Eastern Michigan      Home      W             31
# 3    2011-09-24  2011      San Diego State      Home      W             28
# 4    2011-10-01  2011            Minnesota      Home      W             58
# ..          ...   ...                  ...       ...    ...            ...
# 167  2024-09-14  2024       Arkansas State      Home      W             28
# 168  2024-09-21  2024  Southern California      Home      W             27
# 169  2024-09-28  2024            Minnesota      Home      W             27
# 170  2024-10-05  2024           Washington      Away      L             17
# 171  2024-10-19  2024             Illinois      Away      L              7
#
#      points_against  pass_cmp  pass_att  pass_pct  pass_yrds  pass_td  \
# 0                10         9        13      69.2         98        0
# 1                31        11        24      45.8        338        4
# 2                 3         7        18      38.9         95        2
# 3                 7         8        17      47.1         93        0
# 4                 0        18        25      72.0        217        3
# ..              ...       ...       ...       ...        ...      ...
# 167              18        13        18      72.2        134        1
# 168              24         7        12      58.3         32        0
# 169              24        10        18      55.6         86        1
# 170              27        13        25      52.0        113        1
# 171              21        20        32      62.5        208        0
#
#      pass_1st_down  rush_att  rush_yrds  rush_td  rush_1st_down  \
# 0                5        26        190        3              9
# 1               10        26        114        1              5
# 2                5        50        376        2             19
# 3                3        45        320        4             14
# 4               10        48        363        3             19
# ..             ...       ...        ...      ...            ...
# 167              6        44        301        3             14
# 168              0        46        290        3             12
# 169              5        43        155        2              9
# 170              7        37        174        1              9
# 171              8        38        114        1             10
#
#      total_offense  fumbles  ints
# 0              288        0     0
# 1              452        0     3
# 2              471        0     1
# 3              413        2     2
# 4              580        0     0
# ..             ...      ...   ...
# 167            435        0     3
# 168            322        2     0
# 169            241        0     1
# 170            287        1     1
# 171            322        2     1
#
# [172 rows x 20 columns]

# %% [markdown]
# #### Modifying DataFrame Columns

# %%
# check column information with .columns
df.columns
# Out:
# Index(['date', 'year', 'opponent', 'home_away', 'result', 'points_scored',
#        'points_against', 'pass_cmp', 'pass_att', 'pass_pct', 'pass_yrds',
#        'pass_td', 'pass_1st_down', 'rush_att', 'rush_yrds', 'rush_td',
#        'rush_1st_down', 'total_offense', 'fumbles', 'ints'],
#       dtype='object')

# %%
# .rename() allows us to rename our columns
df.rename(columns = {
    'home_away' : 'location',
    'points_scored' : 'pts_scored',
    'points_against' : 'pts_against',
    'pass_td' : 'pass_tds',
    'pass_1st_down' : 'pass_first_downs',
    'rush_td' : 'rush_tds',
    'rush_1st_down' : 'rush_first_downs'
}, inplace = True)
df.columns
# Out:
# Index(['date', 'year', 'opponent', 'location', 'result', 'pts_scored',
#        'pts_against', 'pass_cmp', 'pass_att', 'pass_pct', 'pass_yrds',
#        'pass_tds', 'pass_first_downs', 'rush_att', 'rush_yrds', 'rush_tds',
#        'rush_first_downs', 'total_offense', 'fumbles', 'ints'],
#       dtype='object')

# %%
# Even though the values of year are numeric, we are treating it as a categorical variable
# We can change year to an object type using .astype()
df.year = df.year.astype('object') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              172 non-null    object
#  1   year              172 non-null    object
#  2   opponent          172 non-null    object
#  3   location          172 non-null    object
#  4   result            172 non-null    object
#  5   pts_scored        172 non-null    int64
#  6   pts_against       172 non-null    int64
#  7   pass_cmp          172 non-null    int64
#  8   pass_att          172 non-null    int64
#  9   pass_pct          172 non-null    float64
#  10  pass_yrds         172 non-null    int64
#  11  pass_tds          172 non-null    int64
#  12  pass_first_downs  172 non-null    int64
#  13  rush_att          172 non-null    int64
#  14  rush_yrds         172 non-null    int64
#  15  rush_tds          172 non-null    int64
#  16  rush_first_downs  172 non-null    int64
#  17  total_offense     172 non-null    int64
#  18  fumbles           172 non-null    int64
#  19  ints              172 non-null    int64
# dtypes: float64(1), int64(14), object(5)
# memory usage: 27.0+ KB

# %% [markdown]
# ### Indexing into our DataFrame

# %% [markdown]
# To access a column, we can use bracket notation.

# %%
# .describe() gets us a numerical summary of each column that uses numbers
# .round() formats the output
df.describe().round(3)
# Out:
#        pts_scored  pts_against  pass_cmp  pass_att  pass_pct  pass_yrds  \
# count     172.000      172.000   172.000   172.000   172.000    172.000
# mean       32.227       18.895    16.523    27.419    60.609    210.773
# std        14.409       12.427     5.619     8.271    11.190     82.726
# min         0.000        0.000     7.000     8.000    33.300     32.000
# 25%        21.000       10.000    13.000    22.000    52.500    159.500
# 50%        31.000       17.000    16.000    27.000    60.000    206.000
# 75%        42.000       26.250    20.000    32.000    68.375    250.250
# max        78.000       62.000    33.000    52.000    87.500    503.000
#
#        pass_tds  pass_first_downs  rush_att  rush_yrds  rush_tds  \
# count   172.000           172.000   172.000    172.000   172.000
# mean      1.488             9.413    39.483    183.407     2.267
# std       1.300             3.766     8.507     91.127     1.692
# min       0.000             0.000    15.000    -48.000     0.000
# 25%       0.000             7.000    34.000    117.000     1.000
# 50%       1.000             9.000    39.500    168.500     2.000
# 75%       2.000            11.250    45.000    249.750     3.000
# max       6.000            21.000    61.000    486.000     9.000
#
#        rush_first_downs  total_offense  fumbles     ints
# count           172.000        172.000  172.000  172.000
# mean              9.436        394.180    0.500    0.837
# std               4.141        106.905    0.729    0.947
# min               0.000        158.000    0.000    0.000
# 25%               6.750        311.500    0.000    0.000
# 50%               9.000        402.500    0.000    1.000
# 75%              12.000        460.250    1.000    1.000
# max              20.000        751.000    3.000    5.000

# %%
df['pts_scored'].describe()
# Out:
# count    172.000000
# mean      32.226744
# std       14.409256
# min        0.000000
# 25%       21.000000
# 50%       31.000000
# 75%       42.000000
# max       78.000000
# Name: pts_scored, dtype: float64

# %%
# This returns a series
df['opponent']
# Out:
# 0         Western Michigan
# 1               Notre Dame
# 2         Eastern Michigan
# 3          San Diego State
# 4                Minnesota
#               ...
# 167         Arkansas State
# 168    Southern California
# 169              Minnesota
# 170             Washington
# 171               Illinois
# Name: opponent, Length: 172, dtype: object

# %%
# This returns a df
df[['opponent']]
# Out:
#                 opponent
# 0       Western Michigan
# 1             Notre Dame
# 2       Eastern Michigan
# 3        San Diego State
# 4              Minnesota
# ..                   ...
# 167       Arkansas State
# 168  Southern California
# 169            Minnesota
# 170           Washington
# 171             Illinois
#
# [172 rows x 1 columns]

# %%
# This returns a df with multiple columns
df[['opponent', 'result']]
# Out:
#                 opponent result
# 0       Western Michigan      W
# 1             Notre Dame      W
# 2       Eastern Michigan      W
# 3        San Diego State      W
# 4              Minnesota      W
# ..                   ...    ...
# 167       Arkansas State      W
# 168  Southern California      W
# 169            Minnesota      W
# 170           Washington      L
# 171             Illinois      L
#
# [172 rows x 2 columns]

# %%
# .value_counts() lets us count the number of times a specific value is in the column
# using .head(n) to show the n most frequent opponents
df['opponent'].value_counts().head(20)
# Out:
# opponent
# Michigan State      13
# Ohio State          12
# Penn State          11
# Indiana             11
# Rutgers             10
# Minnesota            9
# Maryland             9
# Iowa                 8
# Northwestern         7
# Nebraska             7
# Wisconsin            6
# Illinois             6
# Notre Dame           6
# Purdue               5
# Washington           3
# Florida              3
# Western Michigan     3
# Alabama              3
# Connecticut          2
# South Carolina       2
# Name: count, dtype: int64

# %%
# .corr(numeric_only=true) shows us the correlation between any combination of columns that have numbers
# Values closer to 1 indicate a higher correlation between variables
corr_df = df.corr(numeric_only=True)
corr_df
# Out:
#                   pts_scored  pts_against  pass_cmp  pass_att  pass_pct  \
# pts_scored          1.000000    -0.306179  0.098779 -0.210718  0.510223
# pts_against        -0.306179     1.000000  0.240822  0.459252 -0.277354
# pass_cmp            0.098779     0.240822  1.000000  0.843498  0.423930
# pass_att           -0.210718     0.459252  0.843498  1.000000 -0.102644
# pass_pct            0.510223    -0.277354  0.423930 -0.102644  1.000000
# pass_yrds           0.361098     0.244240  0.744645  0.588409  0.387924
# pass_tds            0.543833     0.020559  0.335489  0.144588  0.349843
# pass_first_downs    0.231234     0.221087  0.825911  0.671368  0.403084
# rush_att            0.397414    -0.341835 -0.255992 -0.374491  0.108266
# rush_yrds           0.598019    -0.431584 -0.357629 -0.531696  0.201247
# rush_tds            0.727049    -0.347385 -0.173476 -0.401626  0.334109
# rush_first_downs    0.510027    -0.371176 -0.226509 -0.395850  0.217803
# total_offense       0.789188    -0.178888  0.271380  0.002103  0.471732
# fumbles            -0.228934     0.176112 -0.008560  0.140538 -0.248519
# ints               -0.370450     0.303079 -0.033344  0.164747 -0.304671
#
#                   pass_yrds  pass_tds  pass_first_downs  rush_att  rush_yrds  \
# pts_scored         0.361098  0.543833          0.231234  0.397414   0.598019
# pts_against        0.244240  0.020559          0.221087 -0.341835  -0.431584
# pass_cmp           0.744645  0.335489          0.825911 -0.255992  -0.357629
# pass_att           0.588409  0.144588          0.671368 -0.374491  -0.531696
# pass_pct           0.387924  0.349843          0.403084  0.108266   0.201247
# pass_yrds          1.000000  0.561841          0.859077 -0.191715  -0.246671
# pass_tds           0.561841  1.000000          0.424402 -0.025666   0.068164
# pass_first_downs   0.859077  0.424402          1.000000 -0.189504  -0.298617
# rush_att          -0.191715 -0.025666         -0.189504  1.000000   0.670979
# rush_yrds         -0.246671  0.068164         -0.298617  0.670979   1.000000
# rush_tds           0.028424 -0.049086         -0.033938  0.447171   0.661291
# rush_first_downs  -0.174737  0.082966         -0.255704  0.747992   0.855832
# total_offense      0.563563  0.492873          0.410232  0.423596   0.661532
# fumbles           -0.047725 -0.141832         -0.071303  0.029684  -0.110842
# ints               0.016093 -0.106023          0.004193 -0.250720  -0.262555
#
#                   rush_tds  rush_first_downs  total_offense   fumbles  \
# pts_scored        0.727049          0.510027       0.789188 -0.228934
# pts_against      -0.347385         -0.371176      -0.178888  0.176112
# pass_cmp         -0.173476         -0.226509       0.271380 -0.008560
# pass_att         -0.401626         -0.395850       0.002103  0.140538
# pass_pct          0.334109          0.217803       0.471732 -0.248519
# pass_yrds         0.028424         -0.174737       0.563563 -0.047725
# pass_tds         -0.049086          0.082966       0.492873 -0.141832
# pass_first_downs -0.033938         -0.255704       0.410232 -0.071303
# rush_att          0.447171          0.747992       0.423596  0.029684
# rush_yrds         0.661291          0.855832       0.661532 -0.110842
# rush_tds          1.000000          0.521521       0.585688 -0.118428
# rush_first_downs  0.521521          1.000000       0.594306 -0.093890
# total_offense     0.585688          0.594306       1.000000 -0.131414
# fumbles          -0.118428         -0.093890      -0.131414  1.000000
# ints             -0.308305         -0.262072      -0.211352  0.067701
#
#                       ints
# pts_scored       -0.370450
# pts_against       0.303079
# pass_cmp         -0.033344
# pass_att          0.164747
# pass_pct         -0.304671
# pass_yrds         0.016093
# pass_tds         -0.106023
# pass_first_downs  0.004193
# rush_att         -0.250720
# rush_yrds        -0.262555
# rush_tds         -0.308305
# rush_first_downs -0.262072
# total_offense    -0.211352
# fumbles           0.067701
# ints              1.000000

# %% [markdown]
# #### Accessing Rows of a DataFrame

# %% [markdown]
# There are two ways to access a row using indices:
# * `loc[]` requires label indexing
# * `iloc[]` uses integer indexing

# %%
# .set_index() to existing column
alt_df = df.set_index('date')
alt_df.head(5)
# Out:
#             year          opponent location result  pts_scored  pts_against  \
# date
# 2011-09-03  2011  Western Michigan     Home      W          34           10
# 2011-09-10  2011        Notre Dame     Home      W          35           31
# 2011-09-17  2011  Eastern Michigan     Home      W          31            3
# 2011-09-24  2011   San Diego State     Home      W          28            7
# 2011-10-01  2011         Minnesota     Home      W          58            0
#
#             pass_cmp  pass_att  pass_pct  pass_yrds  pass_tds  \
# date
# 2011-09-03         9        13      69.2         98         0
# 2011-09-10        11        24      45.8        338         4
# 2011-09-17         7        18      38.9         95         2
# 2011-09-24         8        17      47.1         93         0
# 2011-10-01        18        25      72.0        217         3
#
#             pass_first_downs  rush_att  rush_yrds  rush_tds  rush_first_downs  \
# date
# 2011-09-03                 5        26        190         3                 9
# 2011-09-10                10        26        114         1                 5
# 2011-09-17                 5        50        376         2                19
# 2011-09-24                 3        45        320         4                14
# 2011-10-01                10        48        363         3                19
#
#             total_offense  fumbles  ints
# date
# 2011-09-03            288        0     0
# 2011-09-10            452        0     3
# 2011-09-17            471        0     1
# 2011-09-24            413        2     2
# 2011-10-01            580        0     0

# %%
# Returns a Series
row1_loc = alt_df.loc['2011-09-10']
row1_loc
# Out:
# year                      2011
# opponent            Notre Dame
# location                  Home
# result                       W
# pts_scored                  35
# pts_against                 31
# pass_cmp                    11
# pass_att                    24
# pass_pct                  45.8
# pass_yrds                  338
# pass_tds                     4
# pass_first_downs            10
# rush_att                    26
# rush_yrds                  114
# rush_tds                     1
# rush_first_downs             5
# total_offense              452
# fumbles                      0
# ints                         3
# Name: 2011-09-10, dtype: object

# %%
row1_iloc = alt_df.iloc[1]
row1_iloc
# Out:
# year                      2011
# opponent            Notre Dame
# location                  Home
# result                       W
# pts_scored                  35
# pts_against                 31
# pass_cmp                    11
# pass_att                    24
# pass_pct                  45.8
# pass_yrds                  338
# pass_tds                     4
# pass_first_downs            10
# rush_att                    26
# rush_yrds                  114
# rush_tds                     1
# rush_first_downs             5
# total_offense              452
# fumbles                      0
# ints                         3
# Name: 2011-09-10, dtype: object

# %%
# To access multiple rows, we can slice the df
hoke_era = df.iloc[:51]
hoke_era
# Out:
#           date  year           opponent location result  pts_scored  \
# 0   2011-09-03  2011   Western Michigan     Home      W          34
# 1   2011-09-10  2011         Notre Dame     Home      W          35
# 2   2011-09-17  2011   Eastern Michigan     Home      W          31
# 3   2011-09-24  2011    San Diego State     Home      W          28
# 4   2011-10-01  2011          Minnesota     Home      W          58
# 5   2011-10-08  2011       Northwestern     Away      W          42
# 6   2011-10-15  2011     Michigan State     Away      L          14
# 7   2011-10-29  2011             Purdue     Home      W          36
# 8   2011-11-05  2011               Iowa     Away      L          16
# 9   2011-11-12  2011           Illinois     Away      W          31
# 10  2011-11-19  2011           Nebraska     Home      W          45
# 11  2011-11-26  2011         Ohio State     Home      W          40
# 12  2012-01-03  2011      Virginia Tech  Neutral      W          23
# 13  2012-09-01  2012            Alabama  Neutral      L          14
# 14  2012-09-08  2012          Air Force     Home      W          31
# 15  2012-09-15  2012      Massachusetts     Home      W          63
# 16  2012-09-22  2012         Notre Dame     Away      L           6
# 17  2012-10-06  2012             Purdue     Away      W          44
# 18  2012-10-13  2012           Illinois     Home      W          45
# 19  2012-10-20  2012     Michigan State     Home      W          12
# 20  2012-10-27  2012           Nebraska     Away      L           9
# 21  2012-11-03  2012          Minnesota     Away      W          35
# 22  2012-11-10  2012       Northwestern     Home      W          38
# 23  2012-11-17  2012               Iowa     Home      W          42
# 24  2012-11-24  2012         Ohio State     Away      L          21
# 25  2013-01-01  2012     South Carolina  Neutral      L          28
# 26  2013-08-31  2013   Central Michigan     Home      W          59
# 27  2013-09-07  2013         Notre Dame     Home      W          41
# 28  2013-09-14  2013              Akron     Home      W          28
# 29  2013-09-21  2013        Connecticut     Away      W          24
# 30  2013-10-05  2013          Minnesota     Home      W          42
# 31  2013-10-12  2013         Penn State     Away      L          40
# 32  2013-10-19  2013            Indiana     Home      W          63
# 33  2013-11-02  2013     Michigan State     Away      L           6
# 34  2013-11-09  2013           Nebraska     Home      L          13
# 35  2013-11-16  2013       Northwestern     Away      W          27
# 36  2013-11-23  2013               Iowa     Away      L          21
# 37  2013-11-30  2013         Ohio State     Home      L          41
# 38  2013-12-28  2013       Kansas State  Neutral      L          14
# 39  2014-08-30  2014  Appalachian State     Home      W          52
# 40  2014-09-06  2014         Notre Dame     Away      L           0
# 41  2014-09-13  2014         Miami (OH)     Home      W          34
# 42  2014-09-20  2014               Utah     Home      L          10
# 43  2014-09-27  2014          Minnesota     Home      L          14
# 44  2014-10-04  2014            Rutgers     Away      L          24
# 45  2014-10-11  2014         Penn State     Home      W          18
# 46  2014-10-25  2014     Michigan State     Away      L          11
# 47  2014-11-01  2014            Indiana     Home      W          34
# 48  2014-11-08  2014       Northwestern     Away      W          10
# 49  2014-11-22  2014           Maryland     Home      L          16
# 50  2014-11-29  2014         Ohio State     Away      L          28
#
#     pts_against  pass_cmp  pass_att  pass_pct  pass_yrds  pass_tds  \
# 0            10         9        13      69.2         98         0
# 1            31        11        24      45.8        338         4
# 2             3         7        18      38.9         95         2
# 3             7         8        17      47.1         93         0
# 4             0        18        25      72.0        217         3
# 5            24        19        28      67.9        362         2
# 6            28        12        31      38.7        168         1
# 7            14        10        17      58.8        196         0
# 8            24        18        38      47.4        196         2
# 9            14         8        15      53.3        139         1
# 10           17        11        19      57.9        180         2
# 11           34        14        17      82.4        167         3
# 12           20        10        22      45.5        128         2
# 13           41        11        27      40.7        200         1
# 14           25        14        25      56.0        208         2
# 15           13        16        25      64.0        291         3
# 16           13        13        25      52.0        138         0
# 17           13         8        16      50.0        105         1
# 18            0         9        15      60.0        174         2
# 19           10        14        30      46.7        163         0
# 20           23         9        27      33.3         93         0
# 21           13        12        18      66.7        234         2
# 22           31        16        30      53.3        286         2
# 23           17        18        23      78.3        314         3
# 24           26        11        20      55.0        171         1
# 25           33        18        37      48.6        214         3
# 26            9        14        21      66.7        221         1
# 27           30        21        33      63.6        294         4
# 28           24        16        30      53.3        248         2
# 29           21        11        23      47.8         97         0
# 30           13        13        17      76.5        235         1
# 31           43        15        29      51.7        240         3
# 32           47        21        29      72.4        503         2
# 33           29        15        30      50.0        216         0
# 34           17        18        27      66.7        196         1
# 35           19        24        43      55.8        226         1
# 36           24        13        28      46.4         98         2
# 37           42        32        47      68.1        451         4
# 38           31        24        38      63.2        196         0
# 39           14        16        19      84.2        210         3
# 40           31        19        32      59.4        189         0
# 41           10        13        22      59.1        184         2
# 42           26        18        39      46.2        190         0
# 43           30        10        25      40.0         88         0
# 44           26        13        22      59.1        178         0
# 45           13        16        26      61.5        192         1
# 46           35        15        31      48.4        125         0
# 47           10        22        29      75.9        220         2
# 48            9        11        24      45.8        109         0
# 49           23        13        24      54.2        106         0
# 50           42        23        33      69.7        251         2
#
#     pass_first_downs  rush_att  rush_yrds  rush_tds  rush_first_downs  \
# 0                  5        26        190         3                 9
# 1                 10        26        114         1                 5
# 2                  5        50        376         2                19
# 3                  3        45        320         4                14
# 4                 10        48        363         3                19
# 5                 14        50        179         4                 8
# 6                  6        36         82         1                 8
# 7                  7        53        339         4                17
# 8                 10        37        127         0                10
# 9                  6        48        223         3                 8
# 10                 6        61        238         4                14
# 11                 8        50        277         2                14
# 12                 7        30         56         0                 3
# 13                 5        29         69         1                 5
# 14                12        31        214         2                 7
# 15                12        43        294         6                14
# 16                 9        41        161         0                 9
# 17                 6        54        304         3                12
# 18                 7        51        353         4                13
# 19                 8        32        163         0                 7
# 20                 7        37         95         0                 5
# 21                 7        41        155         3                 8
# 22                12        32        133         3                 6
# 23                13        39        199         3                 9
# 24                 5        27        108         2                 5
# 25                10        45        141         0                12
# 26                11        47        242         6                 9
# 27                11        39        166         1                11
# 28                10        32        177         2                 8
# 29                 6        49        192         3                11
# 30                10        35        113         4                 7
# 31                 9        54        149         0                 9
# 32                20        54        248         7                15
# 33                 9        29        -48         0                 2
# 34                12        36        -21         0                 0
# 35                15        44        139         1                10
# 36                 5        29         60         0                 4
# 37                21        35        152         2                 9
# 38                 9        15         65         1                 5
# 39                10        36        350         3                12
# 40                12        35        100         0                 6
# 41                 8        45        276         2                15
# 42                 8        36        118         0                11
# 43                 4        28         83         2                 5
# 44                 8        35        158         3                 7
# 45                 7        31         64         0                 5
# 46                 7        26         61         1                 3
# 47                11        35        184         2                 8
# 48                 7        35        147         1                 6
# 49                 8        45        292         1                13
# 50                14        38        121         2                10
#
#     total_offense  fumbles  ints
# 0             288        0     0
# 1             452        0     3
# 2             471        0     1
# 3             413        2     2
# 4             580        0     0
# 5             541        0     3
# 6             250        0     1
# 7             535        0     2
# 8             323        1     1
# 9             362        2     1
# 10            418        0     1
# 11            444        1     0
# 12            184        0     1
# 13            269        0     3
# 14            422        0     1
# 15            585        0     1
# 16            299        1     5
# 17            409        1     0
# 18            527        1     0
# 19            326        0     1
# 20            188        0     3
# 21            389        0     1
# 22            419        1     1
# 23            513        0     1
# 24            279        3     1
# 25            355        1     1
# 26            463        0     3
# 27            460        0     1
# 28            425        1     3
# 29            289        2     2
# 30            348        0     0
# 31            389        1     2
# 32            751        2     0
# 33            168        0     1
# 34            175        0     0
# 35            365        0     0
# 36            158        1     0
# 37            603        1     0
# 38            261        0     1
# 39            560        0     1
# 40            289        1     3
# 41            460        2     1
# 42            308        1     3
# 43            171        1     1
# 44            336        0     1
# 45            256        0     1
# 46            186        1     2
# 47            404        0     1
# 48            256        1     2
# 49            398        0     1
# 50            372        1     1

# %% [markdown]
# To access a specific value within a df, we access by row, and then by column.

# %%
rush_yrds_natty = df.iloc[164]['rush_yrds']
rush_yrds_natty
# Out:
# 303

# %%
rush_off_corr = corr_df['rush_yrds']['total_offense']
rush_off_corr
# Out:
# 0.6615323775014653

# %% [markdown]
# ### Analyzing Data With `groupby()`

# %%
# We can use the .groupby() function to form groups within our df
years = df.groupby('year')

# %%
# We can access each of the groups using the .get_group() function
games2023 = years.get_group(2023)
games2023
# Out:
#            date  year             opponent location result  pts_scored  \
# 150  2023-09-02  2023        East Carolina     Home      W          30
# 151  2023-09-09  2023     Nevada-Las Vegas     Home      W          35
# 152  2023-09-16  2023  Bowling Green State     Home      W          31
# 153  2023-09-23  2023              Rutgers     Home      W          31
# 154  2023-09-30  2023             Nebraska     Away      W          45
# 155  2023-10-07  2023            Minnesota     Away      W          52
# 156  2023-10-14  2023              Indiana     Home      W          52
# 157  2023-10-21  2023       Michigan State     Away      W          49
# 158  2023-11-04  2023               Purdue     Home      W          41
# 159  2023-11-11  2023           Penn State     Away      W          24
# 160  2023-11-18  2023             Maryland     Away      W          31
# 161  2023-11-25  2023           Ohio State     Home      W          30
# 162  2023-12-02  2023                 Iowa  Neutral      W          26
# 163  2024-01-01  2023              Alabama  Neutral      W          27
# 164  2024-01-08  2023           Washington  Neutral      W          34
#
#      pts_against  pass_cmp  pass_att  pass_pct  pass_yrds  pass_tds  \
# 150            3        26        31      83.9        280         3
# 151            7        23        28      82.1        313         2
# 152            6         8        13      61.5        143         2
# 153            7        15        21      71.4        214         1
# 154            7        16        23      69.6        187         3
# 155           10        16        23      69.6        241         1
# 156            7        19        22      86.4        244         4
# 157            0        28        35      80.0        357         4
# 158           13        24        37      64.9        335         0
# 159           15         7         8      87.5         60         0
# 160           24        12        23      52.2        141         0
# 161           24        17        21      81.0        182         1
# 162            0        22        30      73.3        147         0
# 163           20        17        27      63.0        221         3
# 164           13        10        19      52.6        140         0
#
#      pass_first_downs  rush_att  rush_yrds  rush_tds  rush_first_downs  \
# 150                18        31        122         1                 4
# 151                14        33        179         3                 8
# 152                 5        31        169         2                10
# 153                 9        40        201         2                11
# 154                10        51        249         3                15
# 155                 9        33        191         4                 8
# 156                13        42        163         3                 9
# 157                18        34        120         2                 6
# 158                15        34        110         5                 5
# 159                 4        46        227         3                10
# 160                 9        45        150         3                 9
# 161                10        39        156         2                 8
# 162                 9        34         66         2                 3
# 163                10        32        130         1                 5
# 164                 6        38        303         4                10
#
#      total_offense  fumbles  ints
# 150            402        0     0
# 151            492        0     1
# 152            312        1     3
# 153            415        0     0
# 154            436        0     0
# 155            432        0     0
# 156            407        0     0
# 157            477        0     0
# 158            445        1     0
# 159            287        0     0
# 160            291        0     1
# 161            338        0     0
# 162            213        0     0
# 163            351        1     0
# 164            443        0     0

# %%
# We can also use .groupby() paired with other functions to get some key calculations
# Ex: mean of grouped W-L results
results = df.groupby('result', sort=False)
results.mean(numeric_only=True).round(4)
# Out:
#         pts_scored  pts_against  pass_cmp  pass_att  pass_pct  pass_yrds  \
# result
# W          37.5242      13.9758   15.9032   25.0161   63.3935   210.6694
# L          18.5417      31.6042   18.1250   33.6250   53.4167   211.0417
#
#         pass_tds  pass_first_downs  rush_att  rush_yrds  rush_tds  \
# result
# W         1.6855            9.2177   41.7984   214.9677    2.7742
# L         0.9792            9.9167   33.5000   101.8750    0.9583
#
#         rush_first_downs  total_offense  fumbles    ints
# result
# W                10.6290       425.6371   0.4032  0.6048
# L                 6.3542       312.9167   0.7500  1.4375

# %%
# .mean() with single column
years.mean(numeric_only=True)['rush_tds']
# Out:
# year
# 2011    2.384615
# 2012    2.076923
# 2013    2.076923
# 2014    1.416667
# 2015    2.076923
# 2016    3.153846
# 2017    2.000000
# 2018    2.000000
# 2019    2.000000
# 2020    2.000000
# 2021    2.785714
# 2022    2.928571
# 2023    2.666667
# 2024    1.428571
# Name: rush_tds, dtype: float64

# %%
# .sum()
results.sum(numeric_only=True)
# Out:
#         pts_scored  pts_against  pass_cmp  pass_att  pass_pct  pass_yrds  \
# result
# W             4653         1733      1972      3102    7860.8      26123
# L              890         1517       870      1614    2564.0      10130
#
#         pass_tds  pass_first_downs  rush_att  rush_yrds  rush_tds  \
# result
# W            209              1143      5183      26656       344
# L             47               476      1608       4890        46
#
#         rush_first_downs  total_offense  fumbles  ints
# result
# W                   1318          52779       50    75
# L                    305          15020       36    69

# %%
# .max()
results.max(numeric_only=True)
# Out:
#         pts_scored  pts_against  pass_cmp  pass_att  pass_pct  pass_yrds  \
# result
# W               78           47        33        48      87.5        503
# L               45           62        32        52      69.7        451
#
#         pass_tds  pass_first_downs  rush_att  rush_yrds  rush_tds  \
# result
# W              6                20        61        486         9
# L              4                21        54        292         3
#
#         rush_first_downs  total_offense  fumbles  ints
# result
# W                     20            751        3     3
# L                     13            603        3     5

# %%
# .min()
results.min(numeric_only=True)
# Out:
#         pts_scored  pts_against  pass_cmp  pass_att  pass_pct  pass_yrds  \
# result
# W               10            0         7         8      38.9         32
# L                0           13         9        20      33.3         88
#
#         pass_tds  pass_first_downs  rush_att  rush_yrds  rush_tds  \
# result
# W              0                 0        26         56         0
# L              0                 3        15        -48         0
#
#         rush_first_downs  total_offense  fumbles  ints
# result
# W                      3            184        0     0
# L                      0            158        0     0

# %%
# .median()
results.median(numeric_only=True)
# Out:
#         pts_scored  pts_against  pass_cmp  pass_att  pass_pct  pass_yrds  \
# result
# W             35.0         13.0      16.0      25.0      63.8      208.0
# L             16.0         30.0      18.0      33.0      53.0      199.0
#
#         pass_tds  pass_first_downs  rush_att  rush_yrds  rush_tds  \
# result
# W            2.0               9.0      41.5      198.5       3.0
# L            1.0               9.0      35.0       96.5       1.0
#
#         rush_first_downs  total_offense  fumbles  ints
# result
# W                   10.0          433.5      0.0   0.0
# L                    6.0          299.5      1.0   1.0
